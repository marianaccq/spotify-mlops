# %%
import pandas as pd

# %%
df_spotify = pd.read_csv('genres_v2.csv')
# Out:
# /home/mariana/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_spotify.drop(columns=[ 'key','uri', 'track_href', 'analysis_url', 'id', 'time_signature','song_name', 'Unnamed: 0', 'title', 'type', 'mode', 'tempo'], inplace=True)

# %%
df_spotify.genre.unique()
# Out:
# array(['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB',
#        'Pop', 'Hiphop', 'techhouse', 'techno', 'trance', 'psytrance',
#        'trap', 'dnb', 'hardstyle'], dtype=object)

# %%
df_spotify=df_spotify[(df_spotify.genre!='Dark Trap') & (df_spotify.genre!='RnB') &
          (df_spotify.genre!='Underground Rap') & (df_spotify.genre!='psytrance') &
          (df_spotify.genre!='techhouse') & (df_spotify.genre!='Emo') &
          (df_spotify.genre!='dnb') & (df_spotify.genre!='hardstyle') &
          (df_spotify.genre!='Trap Metal') & (df_spotify.genre!='techno')]

# %%
df_spotify.genre.unique()
# Out:
# array(['Rap', 'Pop', 'Hiphop', 'trance', 'trap'], dtype=object)

# %%
df_spotify = pd.concat([df_spotify[df_spotify.genre=='Rap'].sample(n=1000),
                       df_spotify[df_spotify.genre=='Pop'].sample(n=461),
                       df_spotify[df_spotify.genre=='Hiphop'].sample(n=1000),
                       df_spotify[df_spotify.genre=='trance'].sample(n=1000),
                       df_spotify[df_spotify.genre=='trap'].sample(n=1000)])

# %%
df_spotify
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 14765         0.837   0.626    -4.697       0.2120      0.067500
# 15216         0.511   0.413   -10.839       0.0725      0.603000
# 15655         0.603   0.649    -5.887       0.1170      0.105000
# 14335         0.737   0.597    -7.333       0.1180      0.292000
# 15268         0.482   0.781    -5.334       0.4110      0.629000
# ...             ...     ...       ...          ...           ...
# 34110         0.637   0.973    -1.545       0.0476      0.000067
# 35562         0.629   0.971    -4.191       0.1400      0.002250
# 33910         0.535   0.916    -1.628       0.0544      0.006010
# 35817         0.533   0.946    -2.439       0.2410      0.002430
# 33638         0.515   0.974    -2.461       0.5060      0.000533
#
#        instrumentalness  liveness  valence    tempo  duration_ms genre
# 14765          0.000000    0.2570   0.1140   95.987       162000   Rap
# ...

# %%
df.drop(columns=[ 'key','uri', 'track_href', 'analysis_url', 'id', 'time_signature','song_name', 'Unnamed: 0', 'title', 'type', 'mode'], inplace=True)

# %%
df=df[(df.genre!='Dark Trap') & (df.genre!='RnB') &
          (df.genre!='Underground Rap') & (df.genre!='psytrance') &
          (df.genre!='techhouse')]

# %%
df
# Out:
#               danceability              energy key             loudness mode  \
# 0                    0.831  0.8140000000000001   2               -7.364    1
# 1       0.7190000000000001               0.493   8                -7.23    1
# 2                     0.85               0.893   5               -4.783    1
# 3      0.47600000000000003  0.7809999999999999   0                -4.71    1
# 4       0.7979999999999999               0.624   2   -7.667999999999999    1
# ...                    ...                 ...  ..                  ...  ...
# 42300                0.528               0.693   4               -5.148    1
# 42301                0.517               0.768   0  -7.9220000000000015    0
# 42302                0.361               0.821   8               -3.102    1
# 42303                0.477               0.921   6               -4.777    0
# 42304                0.529               0.945   9               -5.862    1
#
# ...
